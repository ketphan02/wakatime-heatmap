# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

data = pd.read_json('./data.json')

# %%
time_spend = [info['total_seconds'] for info in data['grand_total']]

# %%
time_frame = pd.to_datetime([info['date'] for info in data['range']])

# %%
df = pd.DataFrame(time_spend).reset_index().rename(columns={ 'index': 'Day', 0: 'Time spent' })
df
# Out:
#     Day    Time spent
# 0     0      0.000000
# 1     1      0.000000
# 2     2      0.000000
# 3     3   1259.446764
# 4     4   4426.147958
# 5     5    479.316319
# 6     6     30.031416
# 7     7     46.115543
# 8     8   6337.987273
# 9     9   1337.784438
# 10   10     44.657462
# 11   11     26.433368
# 12   12   3694.000000
# 13   13     92.761626
# 14   14      0.000000
# 15   15   9669.287057
# 16   16   1469.546844
# 17   17    420.555330
# 18   18      0.000000
# 19   19   1703.453064
# 20   20    851.702631
# 21   21   1294.828839
# 22   22   4453.522942
# 23   23   7263.622647
# 24   24   9433.925493
# 25   25  26057.964610
# 26   26  36968.000000
# 27   27  15439.000000
# 28   28  18264.000000
# 29   29  23657.000000

# %%
import numpy as np; np.random.seed(sum(map(ord, 'calplot')))
import pandas as pd
import calplot
import calmap

all_days = pd.date_range('1/1/2019', periods=730, freq='D')
days = np.random.choice(all_days, 500)
events = pd.Series(time_spend, index=time_frame)

# %%
calmap.calendarplot(events, fig_kws=dict(figsize=(15, 8)))
# Out:
# (<Figure size 1080x576 with 1 Axes>,
#  array([<AxesSubplot:ylabel='2021'>], dtype=object))
